# %% [markdown]
# # ORIE 5580 Assignment 1
#
# #### Students: Yik Hau, Au (ya293), Dionisius Davido Tjajono (Dt565)

# %% [markdown]
# ### Instructions
#
#
# * Due Thursday September 4, at 11.59pm on Gradescope.
# * Assignment .ipynb files available for download on [Canvas](https://canvas.cornell.edu/courses/80773/modules#:~:text=Assignments-,Assignments,-Assignments%20module%20publish).
# * Do all your work in provided notebook (text answers typeset in markdown; show all required code and generate plots inline), and then generate and submit a pdf.
# * Ideally do assignments in groups of 2, and submit a single pdf with both names
# * Please show your work and clearly mark your answers.
# * You can use any code fragments given in class, found online (for example, on StackOverflow), or generated via Gemini/Claude/ChatGPT (you are encouraged to use these for first drafts) **with proper referencing**.
# * You can also discuss with others (again, please reference them if you do so); but you must write your final answers on your own as a team.
#
#
#
# ### Suggested reading
#
# Chapters 1 and 2 of [Introduction to Probability](https://chance.dartmouth.edu/teaching_aids/books_articles/probability_book/book.html) by Grinstead and Snell (This textbook tries to teach probability from a 'simulation-first' perspective. Some of you may also enjoy the historical remarks!)

# %% [markdown]
# ## Q1:
#
# The probability density function of the random variable $X$ is given by
# \begin{align*}
# f_X(x) =
# \begin{cases}
# \frac{1}{x} &\mbox{ if $c\leq x \leq 1$,} \\
# 0 & \mbox{otherwise}.
# \end{cases}
# \end{align*}

# %% [markdown]
# **a.** What is the value of the constant $c$?
#
# ---

# %% [markdown]
# ### Ans.
#
# Fill in answer

# %% [markdown]
# $\int_{-∞}^∞ 1/x\, dx  = 1$ \
# $\int_{c}^1 1/x\, dx + 0  = 1$ \
# $\ln(1) - \ln(c) = 1$ \
# $c = e^{-1}$

# %% [markdown]
# ---
#
# **b.** Compute the cdf $F_X(x)$ and mean $\mathbb{E}[X]$ of $X$?
#
# ---

# %% [markdown]
# ### Ans.
#
# Fill in answer

# %% [markdown]
# $F_X(x) = \int_{-∞}^{x} f_X(x)\, dx = \begin{cases}1 &\text{if x > 1} \\ \ln(x) +1 &\text{if c $\leq$ x $\leq$ 1} \\ 0 &\text{if x < c} \end{cases}$ \$
#
# $E_{X}(x) = \int_{-∞}^∞ x * f_{X}(x)\, dx $\
# $ = \int_{c}^a x * 1/x\ + 0, dx $\
# $= 1-e^{-1} $

# %% [markdown]
# ---
#
#
# **c.** Consider the random variable $Y = 1+\ln(X)$. Compute the cdf $F_Y(y)$. Based on this, can you identify the distribution of $Y$?
#
#
# ---

# %% [markdown]
# $F_{Y}(y) = P(Y \leq y) = P(1+\ln(X)<y) = P(X<e^{y-1}) $ \
# $F_X(e^{y-1}) = ln(e^{y-1})+1 = y$, for $0 \leq y \leq 1$ \
# $f_Y(y) = 1 $ \
# The uniform distribution with a = 0, b =1

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
#
#
# **d.** Now let $U\sim U[0,1]$ be a uniformly distributed random variable on $[0,1]$, and consider the random variable $Z = e^{U-1}$. Compute the pdf $f_Z(z)$.
#
#
# ---

# %% [markdown]
# $F_{U}(u) = \int_{0}^u f_U(u)\, du = u$ \
# Then $U = \ln(Z) + 1 $ \
# Consider $ 0 \leq \ln(z) + 1 \leq 1$, then $e^{-1} \leq z \leq 1$ \
# $F_{Z}(z) = P(Z \leq z) = P(U \leq \ln(z)+1) = \begin{cases}1 &\text{if z > 1} \\ \ln(z) +1 &\text{if $e^{-1}$ $\leq$ z $\leq$ 1} \\ 0 &\text{if x < $e^{-1}$} \end{cases}$ \$
#
# $f_Z(z) = \frac{d}{dz}\ F_Z(z) = 1/z$, for $e^{-1}$ $\leq$ z $\leq$ 1

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
#
#
# **e.** **(OPTIONAL)** Now consider a random variable $X$ with cdf $F_X(x)$, and another random variable $Y=F_X(X)$. What is the distribution of $Y$? Next, let $F^{-1}_X(\cdot)$ denote the \emph{inverse} function of $F_X(\cdot)$, i.e., $F_X(x)=y \Leftrightarrow F^{-1}_X(y) = x$, and let $U\sim U[0,1]$ be a uniformly distributed r.v. What is the distribution of $F^{-1}_X(U)$?
#
#
# ---

# %% [markdown]
# $F_Y(y) = P(Y \leq y) = P(X \leq F_X^{-1}(y)) = F_X(F_X^{-1}(y)) = y$ \
# $f_Y(y) = \frac{d}{dy} F_Y(y) = 1$ \
# Y is a uniform distribution with a = 0, b = 1 \
# Consider CDF of U: $F_U(u) = \begin{cases}0 &\text{if u < 0} \\ u &\text{if 0 $\leq$ u $\leq$ 1} \\ 1 &\text{if u > 1} \end{cases}$ \
# Denote $Z = F_X(U)^{-1}$, \
# $F_Z(z) = P(U \leq F_x(z)) = F_U(F_X(z)) $\
# $= \begin{cases}0 &\text{if u < 0} \\ F_X(z) &\text{if 0 $\leq$ u $\leq$ 1} \\ 1 &\text{if u > 1} \end{cases}$ \
# So $F_{X}^{-1}(U)$ ~  X

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Q2:
# Let $X$ and $Y$ be Bernoulli random variables with success probability $p$ and $q$ respectively, i.e.,
# \begin{align*}
# X = \begin{cases} 1 & \text{with probability $p$} \\ 0 & \text{with probability $1-p$} \end{cases}
# \qquad,\qquad
# Y = \begin{cases} 1 & \text{with probability $q$} \\ 0 & \text{with probability $1-q$} \end{cases}
# \end{align*}
# Let $\mathbb{P}( X = 1 \text{ and } Y= 1 ) = \tfrac 13$.

# %% [markdown]
# ---
#
#
# **a.** What is $Cov( X, Y )$?
#
#
# ---

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# E(X) = p*1+0 = p
# E(Y) = q*1+0 = q
# E(XY) = XY*P(X=1,Y=1) + 0 = 1/3
# Cov(X,Y) = E((X-E(Y))(Y-E(X))) = E((X-p)(Y-q)) = E(XY) - E(X)E(Y) = 1/3 - pq

# %% [markdown]
# ---
#
# **b.** For what values of $p$ and $q$ are $X$ and $Y$ uncorrelated?
#
# ---

# %% [markdown]
# pq = 1/3 \
# $0 \leq p \leq 1/(3q)$ \
# $0 \leq q \leq 1/(3p)$

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
#
#
# **c.** Are $X$ and $Y$ independent for the values in (b)?
#
# ---

# %% [markdown]
# if pq = 1/3, \
# then P(X=1, Y=1) = P(X=1)*P(Y=1) = 1/3 <br>
# So yes

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
#
#
# **d.** Suppose you have a function *Bernoulli*$(r)$ that simulates the outcomes of a Bernoulli random variable for any success probability $r$, i.e., it will generate a $1$ with probability $r$ and $0$ with probability $1-r$.
#
# Explain how you can use this function to generate a realization of $X$ and $Y$ above for $p=\tfrac 12$, $q=\tfrac 23$.
#
#
# ---

# %% [markdown]
# Suppose, WLOG, we will generate X then Y, \
# First, we set r = 1/2 for X, then we set r = 2/3 for Y \
# Since they are generated independently, they will be independent.

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
# **e.** Could you also use this function to get a realization of $X$ and $Y$ above if $p=\tfrac 12$, $q=\tfrac 12$ (and $\mathbb{P}( X = 1 \text{ and } Y= 1 ) = \tfrac 13$)?
# Explain how, or why not.
#
# ---

# %% [markdown]
# Since pq $\neq 1/3 = E(XY)$, there is no more independent of X and Y. \
# Then, we will need compute the conditional probability. \
# P(X = 1 and Y = 0) = P(X = 1) - P(X = 1 and Y = 1) = 1/2 - 1/3 = 1/6 \
# simliarly, \
# P(X = 0 and Y = 1) = 1/6 <br>
# P(X = 0 and Y = 0) = 1/3 \
# thus, P(Y = 1 | X = 1) = 1/3 / 1/2 = 2/3 \
# P(Y = 1 | X = 0) = 1/6 / 1/2 = 1/3 \
# Next, we generate the X , set r = 1/2 \
# Finally, we generate Y based on value of X\
# if X = 1, set r = 2/3 \
# else if X = 0, set r = 1/3

# %% [markdown]
# ### Ans.
# Fill in answer

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Q3:
# In Chapter $1$ example $1.4$, Grinstead and Snell talk about measuring two natural quantities associated with the so-called *simple random walk* $S_0 = 0, S_t = S_{t-1}+ X_t$, where $X_t = \pm 1$ with probability $\frac{1}{2}$ (they describe this as a simple betting game between Peter and Paul, where at each time $t$ they toss a fair coin, and if it comes up heads, then Peter wins a penny from Paul, else Paul wins a penny from Peter). We will now replicate their experiments.

# %% [markdown]
# **a.** Generate $n = 1000$ copies of a simple random walk $S^i = (S^i_0,S^i_1,\ldots,S^i_{T})$ (with $T=100$ and $i\in\{1,2,\ldots,n\}$). For each walk, compute $Z^i_T = \frac{S^i_T}{T}$ (i.e., the per-round winnings of Paul after $100$ games), as well as $W^i_T = \frac{1}{T}\sum_{t=1}^{T}\mathbb{1}_{\{S^i_t>0\}}$ (i.e., the fraction of rounds in $[1,T]$ where Paul is in the lead). Plot a histogram of both these quantities (using `plt.hist(data, density=True,bins='auto')`).
#
#
# ---

# %% [markdown]
# ### Ans.
# Fill in answer

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

#initialize
np.random.seed(314)
n = 1000
T = 100
S = []
Z = []
W = []

for i in range(n):
  X = np.random.choice([1, -1], size=T, p=[0.5,0.5])
  s_t = [0]
  z_t = [0]
  for j in range(T): # For each walk
    s_t.append(int(s_t[j] + X[j]))
  S.append(s_t)
  Z.append(int(s_t[T])/T) # Average win per walk (round)
  W.append(sum(1 for x in s_t[1:] if x > 0)/T) # Average lead per walk (round)

# plot Average win per round
plt.hist(Z, density=True, bins='auto')
plt.title('Average win per walk (round)')
plt.show()

# %%
# plot Average lead per round
plt.hist(W, density=True, bins='auto')
plt.title('Average lead per walk (round)')
plt.show()

# %% [markdown]
# **b.** Repeat for $T=1000$ and $T=10000$.

# %% [markdown]
# ### Ans.

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

#initialize
random.seed(40)
n = 1000
T = 1000
S = []
Z = []
W = []

for i in range(n):
  X = np.random.choice([1, -1], size=T, p=[0.5,0.5])
  s_t = [0]
  z_t = [0]
  for j in range(T): # For each walk
    s_t.append(int(s_t[j] + X[j]))
  S.append(s_t)
  Z.append(int(s_t[T])/T) # Average win per walk (round)
  W.append(sum(1 for x in s_t[1:] if x > 0)/T) # Average lead per walk (round)

# plot Average win per round
plt.hist(Z, density=True, bins='auto')
plt.title('Average win per walk (round) with T = 1000')
plt.show()

# %%
plt.hist(W, density=True, bins='auto')
plt.title('Average lead per walk (round) with T = 1000')
plt.show()

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

#initialize
random.seed(40)
n = 1000
T = 10000
S = []
Z = []
W = []

for i in range(n):
  X = np.random.choice([1, -1], size=T, p=[0.5,0.5])
  s_t = [0]
  z_t = [0]
  for j in range(T): # For each walk
    s_t.append(int(s_t[j] + X[j]))
  S.append(s_t)
  Z.append(int(s_t[T])/T) # Average win per walk (round)
  W.append(sum(1 for x in s_t[1:] if x > 0)/T) # Average lead per walk (round)

# plot Average win per round
plt.hist(Z, density=True, bins='auto')
plt.title('Average win per walk (round) with T = 10000')
plt.show()

# %%
plt.hist(W, density=True, bins='auto')
plt.title('Average lead per walk (round) with T = 10000')
plt.show()

# %% [markdown]
# **c.** How do you think the distributions for $Z_T$ and $W_T$ behave as $T→\infty$? Can you give some intuition why this is the case?

# %% [markdown]
# $Z_T$ will behave like a bell shaped normal distribution because  of the central limit theorem, the E($Z_T$) = E($S_T$/T) = 0, Var($Z_T$) = Var($S_T$)/$T^2$ = $T/T^2$ = 1/T \
# $W_T$ will behave like a U-shaped beta (0.5, 0.5) distribution

# %% [markdown]
# ### Ans.

# %% [markdown]
# ---
#
#
#
# ---
# ## Q4:
# As we discuss in class, one major application of simulation is to estimate difficult integrals. In this question, we will perform a simple simulation to estimate the area of a unit circle.

# %% [markdown]
# **a.** Generate $10,000$ points uniformly distributed in $[-1,1]$ and plot a histogram of these points using $50$ uniform-sized bins.
#
# *Hint: See the histogram function in matplotlib; in particular, if your data is stored in an array $X$, then you can use* `<plt.hist(X,bins = 50,density = True)>`
#
#
# ---

# %% [markdown]
# ### Ans.
# See plot below.

# %%
# import library
import numpy as np
import matplotlib.pyplot as plt

n = 10000
data = np.random.uniform(-1, 1, size=n)
plt.hist(data, bins= 50, density= True)
plt.title('Histogram of 10000 unitform random variable')
plt.show()

# %% [markdown]
# ---
#
#
# **b.** Generate $10,000$ points that are uniformly distributed in a square around the origin with corners $(-1,-1),(-1,1),(1,-1)$ and $(1,1)$. To do this, independently generate the $x$- and $y$-coordinates of a point to be uniformly distributed in $(-1,1)$. Create an additional array $Z$ of length $10,000$, which indicates whether each random point lies within a circle of radius $1$ centered at the origin. Plot these points using a scatter plot with different colors for points within the circle and points outside.
#
# *Hint: If you store your coordinate vectors as $X$ and $Y$ and the vector of indicators as $Z$, then use* <plt.scatter(X,Y, c = Z, s = 2.0, cmap=plt.cm.Paired)>
#
#
# ---

# %% [markdown]
# ### Ans.
# See plot below.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10000
X = np.random.uniform(-1, 1, size= n)
Y = np.random.uniform(-1, 1, size= n)
Z = []
for i in range(n):
  if X[i]**2 + Y[i]**2 <= 1: #remark the point inside the circle
    z = 1
  else: #remark the point outside the circle
    z = 0
  Z.append(z)

# plot the scatter plot
plt.scatter(X,Y, c= Z, s= 2.0, cmap= plt.cm.Paired)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Points Inside and Outside the Unit Circle')
plt.show()

# %% [markdown]
# ---
#
#
# **c.** Define $N_{circle}$ to be the (random) number of points which lie within the circle. What is $\mathbb{E}[N_{circle}]$ and $Var(N_{circle})$ (express your answer in terms of $\pi$)?
#
# Suppose also that you did not know the value of $\pi$; can you still argue that $Var(N_{circle})\leq \frac{n}{4}$?
#
#
# ---

# %% [markdown]
# ### Ans.

# %% [markdown]
# The area of the square is 2*2 = 4, the area of the unit circle is $\pi$, the probabily of landing inside the circle is $\pi/4$. Thus, $Z_i$ is a Bernoulli random variable with probability of success is $\pi/4$.
# Then, $E(N_{circle}) = \sum_{i=1}^{n} E(Z_i) = n(\pi/4)$ = \pi/2500 for n = 10000\
# $Var(N_{circle}) = \sum_{i=1}^{n} Var(Z_i) = n * (\pi/4) * (1-\pi/4) = n*(\pi(1-\pi))/16 = 625*(\pi(1-\pi))$ for n = 10000\
# Define $p = \pi/4$, we have $Var(N_{circle}) = n * p * (1-p) = n*(-(p-1/2)^2+1/4)$ by completing the square, which has the maximum value at $p = 1/2$ equal to $n/4$. \
# Therefore, $Var(N_{circle})$ is smaller or equal to $n/4$

# %% [markdown]
# ---
#
#
# **d.** Given $n$ random points generated as in part (b), we can estimate $\pi$ as $\pi_n = \frac{4N_{circle}}{n}$ for $\pi$ (where as before $N_{circle}$ is the random number of points that lie inside the circle). For $n$ between $1$ and $1000$, plot the relative error $|\pi_n - \pi|/\pi$. Also plot the function $1/\sqrt{n}$ on the same plot. How do the relative errors compare to this function?
#
#
# ---

# %% [markdown]
# ### Ans.

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import math

rel_err = []
err_fun = []
pi_n_series = []

for n in range(1,1001):
  X = np.random.uniform(-1, 1, size= n)
  Y = np.random.uniform(-1, 1, size= n)
  Z = []
  for i in range(n):
    if X[i]**2 + Y[i]**2 <= 1: #remark the point inside the circle
      z = 1
    else: #remark the point outside the circle
      z = 0
    Z.append(z)
  N = np.sum(Z)
  pi_n = 4*N/n
  pi_n_series.append(pi_n)
  rel_err.append(abs(pi_n-math.pi)/math.pi)
  err_fun.append(1/math.sqrt(n))

plt.plot(rel_err, label='Relative Error')
plt.plot(err_fun, label='1/sqrt(n) function')
plt.legend()
plt.xlabel('n (Number of Points)')
plt.ylabel('Value')
plt.title('Relative Error of π Estimate and 1/sqrt(n)')
plt.show()

# %% [markdown]
# Both converge to zero as n grow bigger at a similar decay rate, where the value of relative error are mostly below the $1/\sqrt{n}$ function while converging

# %% [markdown]
# ---
# e. Recall that a $95\%$ confidence interval for an estimate is given by $\pi_n \pm \frac{1.96\sqrt{Var(\pi_n)}}{\sqrt{n}}$ (the relative error plot in previous question shows why this is the case). Using your upper bound for $Var(\pi_n)$ from part (c), compute what value of $n$ is required to ensure that the width of the confidence interval is less than $0.001$, and then, simulate using this value $n$ and report an estimate with a $95\%$ confidence interval for $\pi$ that is accurate up to the second digit after the decimal point.
#
#
#
#
# ---

# %% [markdown]
# ### Ans.

# %% [markdown]
# Set $Var(\pi_n) = $, set width of 95% C.I. $1.96*\sqrt{Var(\pi_n)}/\sqrt{n} *2 < 0.001 $ \

# %%
import numpy as np
import math

sd_pi = math.sqrt(np.var(pi_n_series))
n_lwb = (sd_pi*2/0.001)**2

print(f"The Squared root of var(pi_n) = {sd_pi}")
print(f"The lower bound of n = {n_lwb}")
# Out:
# The Squared root of var(pi_n) = 0.17974933066637594
# The lower bound of n = 129239.2875000406

# %%
import numpy as np
import math

n = math.ceil(n_lwb)
print(n)
pi_n_series = []

X = np.random.uniform(-1, 1, size= n)
Y = np.random.uniform(-1, 1, size= n)
Z = []
for i in range(n):
  if X[i]**2 + Y[i]**2 <= 1: #remark the point inside the circle
    z = 1
  else: #remark the point outside the circle
    z = 0
  Z.append(z)
N = np.sum(Z)
pi_n = 4*N/n
print(f"The 95% C.I. for pi_n is ({pi_n-1.96*sd_pi/math.sqrt(n): 2g},{pi_n+1.96*sd_pi/math.sqrt(n):2g})")
# Out:
# 129240
# The 95% C.I. for pi_n is ( 3.13975,3.14171)

# %% [markdown]
# ---
#
# ---
#
#
#
#
# **Q5:** (**For 5580/5581 students; OPTIONAL for 4580**)
#
# Above we used simulation to compute the area of a unit circle. Using a similar process, we can find the volume of a 'sphere' in $n$ dimensions. Estimate this volume for dimensions $d\in\{2,3,\ldots,20\}$, using $100,000$ samples in each dimension. How does your estimate of the volume of the sphere behave as the dimension increases? Also, do your estimates seem smooth or noisy (and if the latter, why)?

# %% [markdown]
# ### Ans.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Obtain pi
n = 100000
V_d = []
dimensions = list(range(2, 21))

for d in dimensions:
  X = np.random.uniform(-1, 1, size= (n, d))
  distance = np.sum(X**2, axis=1)
  Z = np.sum(distance <= 1)
  V_d.append((Z/n) * (2**d))

# Plot
plt.plot(dimensions, V_d, label='Estimated Volume')
plt.title("Simulation for the Volume of D-dimension unit sphere with n = 100000")
plt.xlabel("Dimension")
plt.ylabel("volume")
plt.axvline(x=5, color="red", label='d=5')
plt.legend()
plt.show()

# %% [markdown]
# The volume is estimated to hit it maximum when the dimensions is 5, it decay when d grow bigger after 5. It seems noisy since we are using monte carlo simulation on estimating the volume of the sphere

# %% [markdown]
# ---
#
#
#
# ---
